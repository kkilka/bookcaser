# %%
import pandas

# %%
books = pandas.read_csv('books_sorted2.csv')
books['Ссылка на произведение'] = books['Ссылка на произведение'].replace('/book', 'https://livelib.ru/book', regex=True)
books.sort_values(by=['Автор', 'Произведение']).drop_duplicates().to_csv('books_sorted3.csv', index=False)
